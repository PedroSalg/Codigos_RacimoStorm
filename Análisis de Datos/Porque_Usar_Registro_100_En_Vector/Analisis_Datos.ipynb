# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
# Data 1
Data1 = pd.read_csv('Porque_Usar_Vector_100_1.txt', sep=',')
Data1. columns = ['Muestra']
Name1 = "Pulso 1"

# Data 2
Data2 = pd.read_csv('Porque_Usar_Vector_100_2.txt', sep=',')
Data2. columns = ['Muestra']
Name2 = "Pulso 2"

# Data 3
Data3 = pd.read_csv('Porque_Usar_Vector_100_3.txt', sep=',')
Data3. columns = ['Muestra']
Name3 = "Pulso 3"

# Data 4
Data4 = pd.read_csv('Porque_Usar_Vector_100_4.txt', sep=',')
Data4. columns = ['Muestra']
Name4 = "Pulso 4"

# %%
plt.figure(figsize=(8,5))
plt.title("Registro de pulsos",fontsize=23)
plt.plot(Data1['Muestra'],label=Name1)
plt.plot(Data2['Muestra'],label=Name2)
plt.plot(Data3['Muestra'],label=Name3)
plt.plot(Data4['Muestra'],label=Name4)
plt.grid()
plt.xlabel("Muestras", fontsize=22)
plt.ylabel("Nivel de Cuantización", fontsize=22)
plt.legend(fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig("4_Pulsos_Sin_Vetor.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig_zoom = plt.figure(constrained_layout=True,figsize=(8.0,5.0))
#gs = fig1.add_gridspec(1,1)
ax = plt.axes()
ax.plot(Data2['Muestra'],label=Name2)
ax.grid()
ax.set_title("Pulso 2", fontsize=23)
ax.set_ylabel("Nivel de Cuantización",fontsize=22)
ax.set_xlabel("Muestras", fontsize=22)
ax.tick_params(labelsize='16' ) #labelcolor='r', width=3
#ax.xlabel("Muestras", fontsize=22)
#plt.ylabel("Nivel de Cuantización", fontsize=22)
ax.legend(fontsize=14)
#plt.xticks(fontsize=16)
#plt.yticks(fontsize=16)
#plt.savefig()

# Zoom
x1 = -700
x2 = 1000
# select y-range for zoomed region
y1 = 1540
y2 = 1620
# Make the zoom-in plot:
axins = zoomed_inset_axes(ax, 14, loc='center') # zoom = 2
axins.plot(Data['Muestra'])
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=True)
plt.yticks(visible=True)
mark_inset(ax, axins, loc1=3, loc2=2, fc="none", ec="0.4")
#plt.draw()
#plt.show()

plt.savefig("Pulso_Sin_Vetor.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
