# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes 
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
# Data load
Data1 = pd.read_csv('TEK0006.CSV', sep=',')
Data1. columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

Data2 = pd.read_csv('TEK0007.CSV', sep=',')
Data2. columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

# %%
len(Data1['tie'])
# Out:
# 2499

# %%
fin = 1700
trigger = 43614963
plt.figure(figsize=(8,5))
#plt.title(,fontsize=23)
plt.plot(Data1['tie'][:fin], Data1['dat'][:fin],label='Entrada',color='b')
plt.plot(Data2['tie'][:fin], Data2['dat'][:fin],label='PPS', color='orange')
plt.axvline(0.3+(trigger/1e8),color='red',ls='--',label='Trigger')
#plt.plot(Data4['Muestra'],label=Name4)
plt.grid()
plt.xlabel("Tiempo [s]", fontsize=22)
plt.ylabel("Amplitud [V]", fontsize=22)
plt.legend(fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.text(0.55, 2.5, str(trigger*10)+' ns', color='black', 
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'),fontsize=12)
#plt.savefig("Ancho de evetos grandes.eps")
#plt.savefig("Ancho de evetos grandes.png")
# Out:
# Text(0.55, 2.5, '436149630 ns')

# %%
# Data load
Data3 = pd.read_csv('TEK0004.CSV', sep=',')
Data3. columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

Data4 = pd.read_csv('TEK0005.CSV', sep=',')
Data4. columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

# %%
fin = 1700
trigger = 97040971
plt.figure(figsize=(8,5))
#plt.title(,fontsize=23)
plt.plot(Data3['tie'][:fin], Data3['dat'][:fin],label='Entrada',color='b')
plt.plot(Data4['tie'][:fin], Data4['dat'][:fin],label='PPS', color='orange')
plt.axvline((trigger/1e8 -0.068),color='red',ls='--',label='Trigger')
#plt.plot(Data4['Muestra'],label=Name4)
plt.grid()
plt.xlabel("Tiempo [s]", fontsize=22)
plt.ylabel("Amplitud [V]", fontsize=22)
plt.legend(fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axis([0.0,1.5,-0.2,3.5])
plt.text(0.8, 1.7, str(trigger*10)+' ns', color='black', 
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'),fontsize=12)
#plt.savefig("Ancho de evetos grandes.eps")
#plt.savefig("Ancho de evetos grandes.png")
# Out:
# Text(0.8, 1.7, '970409710 ns')

# %%
# Data load
Data5 = pd.read_csv('TEK0008.CSV', sep=',')
Data5.columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

Data6 = pd.read_csv('TEK0009.CSV', sep=',')
Data6.columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

# %%
fin = len(Data5['tie'])
trigger = 49931293
plt.figure(figsize=(8,5))
#plt.title(,fontsize=23)
plt.plot(Data5['tie'][:], Data5['dat'][:],label='Entrada',color='b')
plt.plot(Data6['tie'][:], Data6['dat'][:],label='PPS', color='orange')
plt.axvline((1.147+trigger/1e8),color='red',ls='--',label='Trigger')
#plt.plot(Data4['Muestra'],label=Name4)
plt.grid()
plt.xlabel("Tiempo [s]", fontsize=22)
plt.ylabel("Amplitud [V]", fontsize=22)
plt.legend(fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axis([0.5,2.4,-0.2,3.5])
plt.text(1.48, 2.5, str(trigger*10)+' ns', color='black', 
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'),fontsize=12)


#plt.savefig("Ancho de evetos grandes.eps")
#plt.savefig("Ancho de evetos grandes.png")
# Out:
# Text(1.48, 2.5, '499312930 ns')

# %%
# Data load
Data7 = pd.read_csv('TEK0010.CSV', sep=',')
Data7.columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

Data8 = pd.read_csv('TEK0011.CSV', sep=',')
Data8.columns = ['M1','M2','M3','tie','dat','M5']
#Name1 = "Pulso 800 ms"

# %%
Data9 = pd.read_csv('Grafica_trigger_1.txt', sep=',')
Data9.columns = ['Data']
#Name1 = "Pulso 800 ms"

# %%
1*5/2
# Out:
# 2.5

# %%
Dat = []
Tim = []
p = 10e-6
trigger = 33480099.0/1e8
for i in range(len(Data9['Data'])-18):
    D = int(Data9['Data'][i])*2/4096
    T = p*i  + trigger + 0.595
    Dat.append((D))
    Tim.append(T)

# %%
trigger = 33480099
plt.figure(figsize=(8,5))
#plt.title(,fontsize=23)
plt.plot(Tim, Dat)
#plt.plot(Data7['tie'][:], Data7['dat'][:],label='Entrada',color='b')
#plt.plot(Data8['tie'][:], Data8['dat'][:],label='PPS', color='orange')
#plt.axvline((0.595+trigger/1e8),color='red',ls='--',label='Trigger')
#plt.plot(Data4['Muestra'],label=Name4)
plt.grid()
plt.xlabel("Tiempo [s]", fontsize=22)
plt.ylabel("Amplitud [V]", fontsize=22)
plt.legend(fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.axis([0.5,3,-0.2,3.5])
#plt.text(1.48, 2.5, str(trigger*10)+' ns', color='black', 
#        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'),fontsize=12)


#plt.savefig("Ancho de evetos grandes.eps")
#plt.savefig("Ancho de evetos grandes.png")
# Out:
# No handles with labels found to put in legend.
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  <a list of 8 Text major ticklabel objects>)

# %%
trigger = 33480099
plt.figure(figsize=(8,5))
#plt.title(,fontsize=23)
plt.plot(Data7['tie'][:], Data7['dat'][:],label='Señal',color='b')
plt.plot(Data8['tie'][:], Data8['dat'][:],label='PPS', color='orange')
plt.axvline((0.595+trigger/1e8),color='red',ls='--',label='Trigger')
plt.plot(Tim, Dat,label="Datos",color='lightgreen')
#plt.plot(Data4['Muestra'],label=Name4)
plt.grid()
plt.xlabel("Tiempo [s]", fontsize=22)
plt.ylabel("Amplitud [V]", fontsize=22)
plt.legend(fontsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.axis([0.5,3,-0.2,3.5])
#plt.text(1.48, 2.5, str(trigger*10)+' ns', color='black', 
#        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'),fontsize=12)


#plt.savefig("Ancho de evetos grandes.eps")
#plt.savefig("Ancho de evetos grandes.png")
# Out:
# (0.5, 3.0, -0.2, 3.5)
